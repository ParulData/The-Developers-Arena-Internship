# %%
name = input("Enter your name : ")
age = int(input("Enter your age : "))
hobby = input("What is your hobby? : ")

print(f"\nWELCOME {name}")
print("Age : ", age)
print("Hobby : ", hobby)
# Out:
# Enter your name :  Parul Yadav
# Enter your age :  23
# What is your hobby? :  Painting
# WELCOME Parul Yadav
# Age :  23
# Hobby :  Painting
